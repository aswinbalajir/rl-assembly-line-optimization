# %%
import simpy
import random

# --- Simulation Parameters ---
STATION_1_TIME = 10       # Mins to process at Station 1
STATION_2_TIME = 20       # Mins to process at Station 2 (The Bottleneck)
STATION_3_TIME = 8        # Mins to process at Station 3
BUFFER_CAPACITY = 10      # Max units a conveyor buffer can hold
INTER_ARRIVAL_TIME = 12   # A new part arrives every 12 minutes on average
SIM_TIME = 1000           # Total simulation time in minutes

# A counter for parts that have successfully completed the line
parts_completed = 0

def part_process(env, part_name, station1, station2, station3, buffer12, buffer23):
    """
    This function simulates the journey of a single part through the assembly line.
    This is a 'generator' function required by SimPy.
    """
    global parts_completed
    print(f"{env.now:.2f}: {part_name} arrives at the assembly line.")

    # --- Process at Station 1 ---
    with station1.request() as req:
        yield req # Request one of the machines at the station
        print(f"{env.now:.2f}: {part_name} starts processing at Station 1.")
        yield env.timeout(STATION_1_TIME)
        print(f"{env.now:.2f}: {part_name} finishes at Station 1.")

    # --- Move to Buffer between Station 1 and 2 ---
    print(f"{env.now:.2f}: {part_name} attempts to move to Buffer 1->2.")
    yield buffer12.put(1) # This will automatically wait if the buffer is full
    # CORRECTED LINE
    print(f"{env.now:.2f}: {part_name} ENTERS Buffer 1->2. (Buffer level: {buffer12.level}/{buffer12.capacity})")

    # --- Process at Station 2 (The Bottleneck) ---
    with station2.request() as req:
        yield buffer12.get(1) # The part is now out of the buffer
        # CORRECTED LINE
        print(f"{env.now:.2f}: {part_name} EXITS Buffer 1->2, moves to Station 2. (Buffer level: {buffer12.level}/{buffer12.capacity})")
        yield req # Request the machine at Station 2
        print(f"{env.now:.2f}: {part_name} starts processing at Station 2.")
        yield env.timeout(STATION_2_TIME)
        print(f"{env.now:.2f}: {part_name} finishes at Station 2.")

    # --- Move to Buffer between Station 2 and 3 ---
    print(f"{env.now:.2f}: {part_name} attempts to move to Buffer 2->3.")
    yield buffer23.put(1)
    # CORRECTED LINE
    print(f"{env.now:.2f}: {part_name} ENTERS Buffer 2->3. (Buffer level: {buffer23.level}/{buffer23.capacity})")

    # --- Process at Station 3 ---
    with station3.request() as req:
        yield buffer23.get(1)
        # CORRECTED LINE
        print(f"{env.now:.2f}: {part_name} EXITS Buffer 2->3, moves to Station 3. (Buffer level: {buffer23.level}/{buffer23.capacity})")
        yield req
        print(f"{env.now:.2f}: {part_name} starts processing at Station 3.")
        yield env.timeout(STATION_3_TIME)
        print(f"{env.now:.2f}: {part_name} finishes at Station 3.")

    print(f"{env.now:.2f}: {part_name} has COMPLETED the line and exits.")
    parts_completed += 1


def part_source(env, station1, station2, station3, buffer12, buffer23):
    """
    This function generates new parts arriving at the assembly line.
    """
    part_id = 0
    while True:
        # Wait for a random time based on the average inter-arrival time
        yield env.timeout(random.expovariate(1.0 / INTER_ARRIVAL_TIME))
        part_id += 1
        # Start the journey for the new part
        env.process(part_process(env, f"Part-{part_id}", station1, station2, station3, buffer12, buffer23))


# --- Setup and Run the Simulation ---
print("--- Starting Assembly Line Simulation ---")
env = simpy.Environment()

# Define the resources for our simulation
# Stations are resources that can be used by one part at a time (capacity=1)
station1 = simpy.Resource(env, capacity=1)
station2 = simpy.Resource(env, capacity=1)
station3 = simpy.Resource(env, capacity=1)

# Buffers are containers that can hold a limited number of parts
buffer12 = simpy.Container(env, capacity=BUFFER_CAPACITY, init=0)
buffer23 = simpy.Container(env, capacity=BUFFER_CAPACITY, init=0)

# Start the part generator
env.process(part_source(env, station1, station2, station3, buffer12, buffer23))

# Run the simulation for the specified time
env.run(until=SIM_TIME)

# --- Simulation Report ---
print("\n--- Simulation Finished ---")
print(f"Total simulation time: {SIM_TIME} minutes.")
print(f"Total parts completed: {parts_completed}.")
throughput = parts_completed / (SIM_TIME / 60) # Units per hour
print(f"Throughput: {throughput:.2f} units per hour.")
# Out:
# Requirement already satisfied: simpy in .\.venv\lib\site-packages (4.1.1)
# --- Starting Assembly Line Simulation ---
# 4.23: Part-1 arrives at the assembly line.
# 4.23: Part-1 starts processing at Station 1.
# 14.23: Part-1 finishes at Station 1.
# 14.23: Part-1 attempts to move to Buffer 1->2.
# 14.23: Part-1 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 14.23: Part-1 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 14.23: Part-1 starts processing at Station 2.
# 20.60: Part-2 arrives at the assembly line.
# 20.60: Part-2 starts processing at Station 1.
# 25.29: Part-3 arrives at the assembly line.
# 25.49: Part-4 arrives at the assembly line.
# 29.43: Part-5 arrives at the assembly line.
# 30.60: Part-2 finishes at Station 1.
# 30.60: Part-2 attempts to move to Buffer 1->2.
# 30.60: Part-2 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 30.60: Part-3 starts processing at Station 1.
# 30.60: Part-2 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 34.23: Part-1 finishes at Station 2.
# 34.23: Part-1 attempts to move to Buffer 2->3.
# 34.23: Part-1 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 34.23: Part-2 starts processing at Station 2.
# 34.23: Part-1 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 34.23: Part-1 starts processing at Station 3.
# 40.60: Part-3 finishes at Station 1.
# 40.60: Part-3 attempts to move to Buffer 1->2.
# 40.60: Part-3 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 40.60: Part-4 starts processing at Station 1.
# 40.60: Part-3 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 42.23: Part-1 finishes at Station 3.
# 42.23: Part-1 has COMPLETED the line and exits.
# 50.60: Part-4 finishes at Station 1.
# 50.60: Part-4 attempts to move to Buffer 1->2.
# 50.60: Part-4 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 50.60: Part-5 starts processing at Station 1.
# 50.60: Part-4 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 54.23: Part-2 finishes at Station 2.
# 54.23: Part-2 attempts to move to Buffer 2->3.
# 54.23: Part-2 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 54.23: Part-3 starts processing at Station 2.
# 54.23: Part-2 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 54.23: Part-2 starts processing at Station 3.
# 60.60: Part-5 finishes at Station 1.
# 60.60: Part-5 attempts to move to Buffer 1->2.
# 60.60: Part-5 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 60.60: Part-5 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 62.23: Part-2 finishes at Station 3.
# 62.23: Part-2 has COMPLETED the line and exits.
# 67.00: Part-6 arrives at the assembly line.
# 67.00: Part-6 starts processing at Station 1.
# 74.23: Part-3 finishes at Station 2.
# 74.23: Part-3 attempts to move to Buffer 2->3.
# 74.23: Part-3 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 74.23: Part-4 starts processing at Station 2.
# 74.23: Part-3 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 74.23: Part-3 starts processing at Station 3.
# 77.00: Part-6 finishes at Station 1.
# 77.00: Part-6 attempts to move to Buffer 1->2.
# 77.00: Part-6 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 77.00: Part-6 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 82.23: Part-3 finishes at Station 3.
# 82.23: Part-3 has COMPLETED the line and exits.
# 94.23: Part-4 finishes at Station 2.
# 94.23: Part-4 attempts to move to Buffer 2->3.
# 94.23: Part-4 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 94.23: Part-5 starts processing at Station 2.
# 94.23: Part-4 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 94.23: Part-4 starts processing at Station 3.
# 96.11: Part-7 arrives at the assembly line.
# 96.11: Part-7 starts processing at Station 1.
# 96.90: Part-8 arrives at the assembly line.
# 102.11: Part-9 arrives at the assembly line.
# 102.23: Part-4 finishes at Station 3.
# 102.23: Part-4 has COMPLETED the line and exits.
# 106.11: Part-7 finishes at Station 1.
# 106.11: Part-7 attempts to move to Buffer 1->2.
# 106.11: Part-7 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 106.11: Part-8 starts processing at Station 1.
# 106.11: Part-7 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 114.23: Part-5 finishes at Station 2.
# 114.23: Part-5 attempts to move to Buffer 2->3.
# 114.23: Part-5 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 114.23: Part-6 starts processing at Station 2.
# 114.23: Part-5 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 114.23: Part-5 starts processing at Station 3.
# 115.17: Part-10 arrives at the assembly line.
# 116.11: Part-8 finishes at Station 1.
# 116.11: Part-8 attempts to move to Buffer 1->2.
# 116.11: Part-8 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 116.11: Part-9 starts processing at Station 1.
# 116.11: Part-8 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 122.23: Part-5 finishes at Station 3.
# 122.23: Part-5 has COMPLETED the line and exits.
# 126.11: Part-9 finishes at Station 1.
# 126.11: Part-9 attempts to move to Buffer 1->2.
# 126.11: Part-9 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 126.11: Part-10 starts processing at Station 1.
# 126.11: Part-9 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 134.23: Part-6 finishes at Station 2.
# 134.23: Part-6 attempts to move to Buffer 2->3.
# 134.23: Part-6 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 134.23: Part-7 starts processing at Station 2.
# 134.23: Part-6 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 134.23: Part-6 starts processing at Station 3.
# 136.11: Part-10 finishes at Station 1.
# 136.11: Part-10 attempts to move to Buffer 1->2.
# 136.11: Part-10 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 136.11: Part-10 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 142.23: Part-6 finishes at Station 3.
# 142.23: Part-6 has COMPLETED the line and exits.
# 144.67: Part-11 arrives at the assembly line.
# 144.67: Part-11 starts processing at Station 1.
# 154.23: Part-7 finishes at Station 2.
# 154.23: Part-7 attempts to move to Buffer 2->3.
# 154.23: Part-7 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 154.23: Part-8 starts processing at Station 2.
# 154.23: Part-7 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 154.23: Part-7 starts processing at Station 3.
# 154.67: Part-11 finishes at Station 1.
# 154.67: Part-11 attempts to move to Buffer 1->2.
# 154.67: Part-11 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 154.67: Part-11 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 162.23: Part-7 finishes at Station 3.
# 162.23: Part-7 has COMPLETED the line and exits.
# 174.23: Part-8 finishes at Station 2.
# 174.23: Part-8 attempts to move to Buffer 2->3.
# 174.23: Part-8 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 174.23: Part-9 starts processing at Station 2.
# 174.23: Part-8 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 174.23: Part-8 starts processing at Station 3.
# 176.67: Part-12 arrives at the assembly line.
# 176.67: Part-12 starts processing at Station 1.
# 182.23: Part-8 finishes at Station 3.
# 182.23: Part-8 has COMPLETED the line and exits.
# 186.67: Part-12 finishes at Station 1.
# 186.67: Part-12 attempts to move to Buffer 1->2.
# 186.67: Part-12 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 186.67: Part-12 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 194.23: Part-9 finishes at Station 2.
# 194.23: Part-9 attempts to move to Buffer 2->3.
# 194.23: Part-9 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 194.23: Part-10 starts processing at Station 2.
# 194.23: Part-9 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 194.23: Part-9 starts processing at Station 3.
# 201.33: Part-13 arrives at the assembly line.
# 201.33: Part-13 starts processing at Station 1.
# 202.23: Part-9 finishes at Station 3.
# 202.23: Part-9 has COMPLETED the line and exits.
# 206.40: Part-14 arrives at the assembly line.
# 211.33: Part-13 finishes at Station 1.
# 211.33: Part-13 attempts to move to Buffer 1->2.
# 211.33: Part-13 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 211.33: Part-14 starts processing at Station 1.
# 211.33: Part-13 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 214.23: Part-10 finishes at Station 2.
# 214.23: Part-10 attempts to move to Buffer 2->3.
# 214.23: Part-10 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 214.23: Part-11 starts processing at Station 2.
# 214.23: Part-10 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 214.23: Part-10 starts processing at Station 3.
# 221.33: Part-14 finishes at Station 1.
# 221.33: Part-14 attempts to move to Buffer 1->2.
# 221.33: Part-14 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 221.33: Part-14 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 222.23: Part-10 finishes at Station 3.
# 222.23: Part-10 has COMPLETED the line and exits.
# 226.73: Part-15 arrives at the assembly line.
# 226.73: Part-15 starts processing at Station 1.
# 234.23: Part-11 finishes at Station 2.
# 234.23: Part-11 attempts to move to Buffer 2->3.
# 234.23: Part-11 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 234.23: Part-12 starts processing at Station 2.
# 234.23: Part-11 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 234.23: Part-11 starts processing at Station 3.
# 236.73: Part-15 finishes at Station 1.
# 236.73: Part-15 attempts to move to Buffer 1->2.
# 236.73: Part-15 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 236.73: Part-15 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 242.23: Part-11 finishes at Station 3.
# 242.23: Part-11 has COMPLETED the line and exits.
# 252.44: Part-16 arrives at the assembly line.
# 252.44: Part-16 starts processing at Station 1.
# 254.23: Part-12 finishes at Station 2.
# 254.23: Part-12 attempts to move to Buffer 2->3.
# 254.23: Part-12 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 254.23: Part-13 starts processing at Station 2.
# 254.23: Part-12 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 254.23: Part-12 starts processing at Station 3.
# 262.11: Part-17 arrives at the assembly line.
# 262.23: Part-12 finishes at Station 3.
# 262.23: Part-12 has COMPLETED the line and exits.
# 262.44: Part-16 finishes at Station 1.
# 262.44: Part-16 attempts to move to Buffer 1->2.
# 262.44: Part-16 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 262.44: Part-17 starts processing at Station 1.
# 262.44: Part-16 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 272.42: Part-18 arrives at the assembly line.
# 272.44: Part-17 finishes at Station 1.
# 272.44: Part-17 attempts to move to Buffer 1->2.
# 272.44: Part-17 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 272.44: Part-18 starts processing at Station 1.
# 272.44: Part-17 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 274.23: Part-13 finishes at Station 2.
# 274.23: Part-13 attempts to move to Buffer 2->3.
# 274.23: Part-13 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 274.23: Part-14 starts processing at Station 2.
# 274.23: Part-13 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 274.23: Part-13 starts processing at Station 3.
# 279.67: Part-19 arrives at the assembly line.
# 282.23: Part-13 finishes at Station 3.
# 282.23: Part-13 has COMPLETED the line and exits.
# 282.44: Part-18 finishes at Station 1.
# 282.44: Part-18 attempts to move to Buffer 1->2.
# 282.44: Part-18 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 282.44: Part-19 starts processing at Station 1.
# 282.44: Part-18 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 292.44: Part-19 finishes at Station 1.
# 292.44: Part-19 attempts to move to Buffer 1->2.
# 292.44: Part-19 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 292.44: Part-19 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 294.23: Part-14 finishes at Station 2.
# 294.23: Part-14 attempts to move to Buffer 2->3.
# 294.23: Part-14 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 294.23: Part-15 starts processing at Station 2.
# 294.23: Part-14 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 294.23: Part-14 starts processing at Station 3.
# 302.23: Part-14 finishes at Station 3.
# 302.23: Part-14 has COMPLETED the line and exits.
# 314.23: Part-15 finishes at Station 2.
# 314.23: Part-15 attempts to move to Buffer 2->3.
# 314.23: Part-15 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 314.23: Part-16 starts processing at Station 2.
# 314.23: Part-15 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 314.23: Part-15 starts processing at Station 3.
# 322.23: Part-15 finishes at Station 3.
# 322.23: Part-15 has COMPLETED the line and exits.
# 334.23: Part-16 finishes at Station 2.
# 334.23: Part-16 attempts to move to Buffer 2->3.
# 334.23: Part-16 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 334.23: Part-17 starts processing at Station 2.
# 334.23: Part-16 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 334.23: Part-16 starts processing at Station 3.
# 342.23: Part-16 finishes at Station 3.
# 342.23: Part-16 has COMPLETED the line and exits.
# 354.23: Part-17 finishes at Station 2.
# 354.23: Part-17 attempts to move to Buffer 2->3.
# 354.23: Part-17 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 354.23: Part-18 starts processing at Station 2.
# 354.23: Part-17 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 354.23: Part-17 starts processing at Station 3.
# 357.51: Part-20 arrives at the assembly line.
# 357.51: Part-20 starts processing at Station 1.
# 357.69: Part-21 arrives at the assembly line.
# 362.23: Part-17 finishes at Station 3.
# 362.23: Part-17 has COMPLETED the line and exits.
# 365.84: Part-22 arrives at the assembly line.
# 367.51: Part-20 finishes at Station 1.
# 367.51: Part-20 attempts to move to Buffer 1->2.
# 367.51: Part-20 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 367.51: Part-21 starts processing at Station 1.
# 367.51: Part-20 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 374.23: Part-18 finishes at Station 2.
# 374.23: Part-18 attempts to move to Buffer 2->3.
# 374.23: Part-18 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 374.23: Part-19 starts processing at Station 2.
# 374.23: Part-18 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 374.23: Part-18 starts processing at Station 3.
# 377.51: Part-21 finishes at Station 1.
# 377.51: Part-21 attempts to move to Buffer 1->2.
# 377.51: Part-21 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 377.51: Part-22 starts processing at Station 1.
# 377.51: Part-21 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 379.71: Part-23 arrives at the assembly line.
# 382.23: Part-18 finishes at Station 3.
# 382.23: Part-18 has COMPLETED the line and exits.
# 387.51: Part-22 finishes at Station 1.
# 387.51: Part-22 attempts to move to Buffer 1->2.
# 387.51: Part-22 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 387.51: Part-23 starts processing at Station 1.
# 387.51: Part-22 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 394.23: Part-19 finishes at Station 2.
# 394.23: Part-19 attempts to move to Buffer 2->3.
# 394.23: Part-19 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 394.23: Part-20 starts processing at Station 2.
# 394.23: Part-19 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 394.23: Part-19 starts processing at Station 3.
# 397.51: Part-23 finishes at Station 1.
# 397.51: Part-23 attempts to move to Buffer 1->2.
# 397.51: Part-23 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 397.51: Part-23 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 402.23: Part-19 finishes at Station 3.
# 402.23: Part-19 has COMPLETED the line and exits.
# 414.23: Part-20 finishes at Station 2.
# 414.23: Part-20 attempts to move to Buffer 2->3.
# 414.23: Part-20 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 414.23: Part-21 starts processing at Station 2.
# 414.23: Part-20 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 414.23: Part-20 starts processing at Station 3.
# 418.29: Part-24 arrives at the assembly line.
# 418.29: Part-24 starts processing at Station 1.
# 422.23: Part-20 finishes at Station 3.
# 422.23: Part-20 has COMPLETED the line and exits.
# 423.90: Part-25 arrives at the assembly line.
# 428.29: Part-24 finishes at Station 1.
# 428.29: Part-24 attempts to move to Buffer 1->2.
# 428.29: Part-24 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 428.29: Part-25 starts processing at Station 1.
# 428.29: Part-24 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 434.23: Part-21 finishes at Station 2.
# 434.23: Part-21 attempts to move to Buffer 2->3.
# 434.23: Part-21 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 434.23: Part-22 starts processing at Station 2.
# 434.23: Part-21 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 434.23: Part-21 starts processing at Station 3.
# 434.49: Part-26 arrives at the assembly line.
# 438.29: Part-25 finishes at Station 1.
# 438.29: Part-25 attempts to move to Buffer 1->2.
# 438.29: Part-25 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 438.29: Part-26 starts processing at Station 1.
# 438.29: Part-25 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 440.04: Part-27 arrives at the assembly line.
# 442.23: Part-21 finishes at Station 3.
# 442.23: Part-21 has COMPLETED the line and exits.
# 448.29: Part-26 finishes at Station 1.
# 448.29: Part-26 attempts to move to Buffer 1->2.
# 448.29: Part-26 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 448.29: Part-27 starts processing at Station 1.
# 448.29: Part-26 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 454.23: Part-22 finishes at Station 2.
# 454.23: Part-22 attempts to move to Buffer 2->3.
# 454.23: Part-22 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 454.23: Part-23 starts processing at Station 2.
# 454.23: Part-22 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 454.23: Part-22 starts processing at Station 3.
# 458.29: Part-27 finishes at Station 1.
# 458.29: Part-27 attempts to move to Buffer 1->2.
# 458.29: Part-27 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 458.29: Part-27 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 462.23: Part-22 finishes at Station 3.
# 462.23: Part-22 has COMPLETED the line and exits.
# 464.05: Part-28 arrives at the assembly line.
# 464.05: Part-28 starts processing at Station 1.
# 470.48: Part-29 arrives at the assembly line.
# 474.05: Part-28 finishes at Station 1.
# 474.05: Part-28 attempts to move to Buffer 1->2.
# 474.05: Part-28 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 474.05: Part-29 starts processing at Station 1.
# 474.05: Part-28 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 474.23: Part-23 finishes at Station 2.
# 474.23: Part-23 attempts to move to Buffer 2->3.
# 474.23: Part-23 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 474.23: Part-24 starts processing at Station 2.
# 474.23: Part-23 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 474.23: Part-23 starts processing at Station 3.
# 482.23: Part-23 finishes at Station 3.
# 482.23: Part-23 has COMPLETED the line and exits.
# 483.03: Part-30 arrives at the assembly line.
# 484.05: Part-29 finishes at Station 1.
# 484.05: Part-29 attempts to move to Buffer 1->2.
# 484.05: Part-29 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 484.05: Part-30 starts processing at Station 1.
# 484.05: Part-29 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 490.74: Part-31 arrives at the assembly line.
# 494.05: Part-30 finishes at Station 1.
# 494.05: Part-30 attempts to move to Buffer 1->2.
# 494.05: Part-30 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 494.05: Part-31 starts processing at Station 1.
# 494.05: Part-30 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 494.23: Part-24 finishes at Station 2.
# 494.23: Part-24 attempts to move to Buffer 2->3.
# 494.23: Part-24 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 494.23: Part-25 starts processing at Station 2.
# 494.23: Part-24 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 494.23: Part-24 starts processing at Station 3.
# 502.23: Part-24 finishes at Station 3.
# 502.23: Part-24 has COMPLETED the line and exits.
# 504.05: Part-31 finishes at Station 1.
# 504.05: Part-31 attempts to move to Buffer 1->2.
# 504.05: Part-31 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 504.05: Part-31 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 508.48: Part-32 arrives at the assembly line.
# 508.48: Part-32 starts processing at Station 1.
# 514.23: Part-25 finishes at Station 2.
# 514.23: Part-25 attempts to move to Buffer 2->3.
# 514.23: Part-25 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 514.23: Part-26 starts processing at Station 2.
# 514.23: Part-25 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 514.23: Part-25 starts processing at Station 3.
# 518.48: Part-32 finishes at Station 1.
# 518.48: Part-32 attempts to move to Buffer 1->2.
# 518.48: Part-32 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 518.48: Part-32 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 522.23: Part-25 finishes at Station 3.
# 522.23: Part-25 has COMPLETED the line and exits.
# 529.61: Part-33 arrives at the assembly line.
# 529.61: Part-33 starts processing at Station 1.
# 534.23: Part-26 finishes at Station 2.
# 534.23: Part-26 attempts to move to Buffer 2->3.
# 534.23: Part-26 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 534.23: Part-27 starts processing at Station 2.
# 534.23: Part-26 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 534.23: Part-26 starts processing at Station 3.
# 537.01: Part-34 arrives at the assembly line.
# 538.79: Part-35 arrives at the assembly line.
# 539.61: Part-33 finishes at Station 1.
# 539.61: Part-33 attempts to move to Buffer 1->2.
# 539.61: Part-33 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 539.61: Part-34 starts processing at Station 1.
# 539.61: Part-33 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 542.23: Part-26 finishes at Station 3.
# 542.23: Part-26 has COMPLETED the line and exits.
# 544.80: Part-36 arrives at the assembly line.
# 546.78: Part-37 arrives at the assembly line.
# 549.61: Part-34 finishes at Station 1.
# 549.61: Part-34 attempts to move to Buffer 1->2.
# 549.61: Part-34 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 549.61: Part-35 starts processing at Station 1.
# 549.61: Part-34 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 554.23: Part-27 finishes at Station 2.
# 554.23: Part-27 attempts to move to Buffer 2->3.
# 554.23: Part-27 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 554.23: Part-28 starts processing at Station 2.
# 554.23: Part-27 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 554.23: Part-27 starts processing at Station 3.
# 559.61: Part-35 finishes at Station 1.
# 559.61: Part-35 attempts to move to Buffer 1->2.
# 559.61: Part-35 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 559.61: Part-36 starts processing at Station 1.
# 559.61: Part-35 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 562.23: Part-27 finishes at Station 3.
# 562.23: Part-27 has COMPLETED the line and exits.
# 569.61: Part-36 finishes at Station 1.
# 569.61: Part-36 attempts to move to Buffer 1->2.
# 569.61: Part-36 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 569.61: Part-37 starts processing at Station 1.
# 569.61: Part-36 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 570.95: Part-38 arrives at the assembly line.
# 574.23: Part-28 finishes at Station 2.
# 574.23: Part-28 attempts to move to Buffer 2->3.
# 574.23: Part-28 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 574.23: Part-29 starts processing at Station 2.
# 574.23: Part-28 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 574.23: Part-28 starts processing at Station 3.
# 579.61: Part-37 finishes at Station 1.
# 579.61: Part-37 attempts to move to Buffer 1->2.
# 579.61: Part-37 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 579.61: Part-38 starts processing at Station 1.
# 579.61: Part-37 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 582.23: Part-28 finishes at Station 3.
# 582.23: Part-28 has COMPLETED the line and exits.
# 586.10: Part-39 arrives at the assembly line.
# 589.61: Part-38 finishes at Station 1.
# 589.61: Part-38 attempts to move to Buffer 1->2.
# 589.61: Part-38 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 589.61: Part-39 starts processing at Station 1.
# 589.61: Part-38 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 592.07: Part-40 arrives at the assembly line.
# 594.23: Part-29 finishes at Station 2.
# 594.23: Part-29 attempts to move to Buffer 2->3.
# 594.23: Part-29 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 594.23: Part-30 starts processing at Station 2.
# 594.23: Part-29 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 594.23: Part-29 starts processing at Station 3.
# 599.61: Part-39 finishes at Station 1.
# 599.61: Part-39 attempts to move to Buffer 1->2.
# 599.61: Part-39 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 599.61: Part-40 starts processing at Station 1.
# 599.61: Part-39 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 602.23: Part-29 finishes at Station 3.
# 602.23: Part-29 has COMPLETED the line and exits.
# 603.34: Part-41 arrives at the assembly line.
# 609.61: Part-40 finishes at Station 1.
# 609.61: Part-40 attempts to move to Buffer 1->2.
# 609.61: Part-40 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 609.61: Part-41 starts processing at Station 1.
# 609.61: Part-40 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 614.23: Part-30 finishes at Station 2.
# 614.23: Part-30 attempts to move to Buffer 2->3.
# 614.23: Part-30 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 614.23: Part-31 starts processing at Station 2.
# 614.23: Part-30 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 614.23: Part-30 starts processing at Station 3.
# 619.61: Part-41 finishes at Station 1.
# 619.61: Part-41 attempts to move to Buffer 1->2.
# 619.61: Part-41 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 619.61: Part-41 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 622.23: Part-30 finishes at Station 3.
# 622.23: Part-30 has COMPLETED the line and exits.
# 624.11: Part-42 arrives at the assembly line.
# 624.11: Part-42 starts processing at Station 1.
# 624.35: Part-43 arrives at the assembly line.
# 634.11: Part-42 finishes at Station 1.
# 634.11: Part-42 attempts to move to Buffer 1->2.
# 634.11: Part-42 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 634.11: Part-43 starts processing at Station 1.
# 634.11: Part-42 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 634.23: Part-31 finishes at Station 2.
# 634.23: Part-31 attempts to move to Buffer 2->3.
# 634.23: Part-31 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 634.23: Part-32 starts processing at Station 2.
# 634.23: Part-31 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 634.23: Part-31 starts processing at Station 3.
# 642.23: Part-31 finishes at Station 3.
# 642.23: Part-31 has COMPLETED the line and exits.
# 644.11: Part-43 finishes at Station 1.
# 644.11: Part-43 attempts to move to Buffer 1->2.
# 644.11: Part-43 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 644.11: Part-43 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 654.23: Part-32 finishes at Station 2.
# 654.23: Part-32 attempts to move to Buffer 2->3.
# 654.23: Part-32 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 654.23: Part-33 starts processing at Station 2.
# 654.23: Part-32 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 654.23: Part-32 starts processing at Station 3.
# 656.74: Part-44 arrives at the assembly line.
# 656.74: Part-44 starts processing at Station 1.
# 662.23: Part-32 finishes at Station 3.
# 662.23: Part-32 has COMPLETED the line and exits.
# 666.74: Part-44 finishes at Station 1.
# 666.74: Part-44 attempts to move to Buffer 1->2.
# 666.74: Part-44 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 666.74: Part-44 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 667.88: Part-45 arrives at the assembly line.
# 667.88: Part-45 starts processing at Station 1.
# 674.23: Part-33 finishes at Station 2.
# 674.23: Part-33 attempts to move to Buffer 2->3.
# 674.23: Part-33 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 674.23: Part-34 starts processing at Station 2.
# 674.23: Part-33 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 674.23: Part-33 starts processing at Station 3.
# 677.88: Part-45 finishes at Station 1.
# 677.88: Part-45 attempts to move to Buffer 1->2.
# 677.88: Part-45 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 677.88: Part-45 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 678.08: Part-46 arrives at the assembly line.
# 678.08: Part-46 starts processing at Station 1.
# 682.23: Part-33 finishes at Station 3.
# 682.23: Part-33 has COMPLETED the line and exits.
# 688.08: Part-46 finishes at Station 1.
# 688.08: Part-46 attempts to move to Buffer 1->2.
# 688.08: Part-46 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 688.08: Part-46 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 694.02: Part-47 arrives at the assembly line.
# 694.02: Part-47 starts processing at Station 1.
# 694.23: Part-34 finishes at Station 2.
# 694.23: Part-34 attempts to move to Buffer 2->3.
# 694.23: Part-34 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 694.23: Part-35 starts processing at Station 2.
# 694.23: Part-34 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 694.23: Part-34 starts processing at Station 3.
# 702.23: Part-34 finishes at Station 3.
# 702.23: Part-34 has COMPLETED the line and exits.
# 704.02: Part-47 finishes at Station 1.
# 704.02: Part-47 attempts to move to Buffer 1->2.
# 704.02: Part-47 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 704.02: Part-47 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 711.25: Part-48 arrives at the assembly line.
# 711.25: Part-48 starts processing at Station 1.
# 714.23: Part-35 finishes at Station 2.
# 714.23: Part-35 attempts to move to Buffer 2->3.
# 714.23: Part-35 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 714.23: Part-36 starts processing at Station 2.
# 714.23: Part-35 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 714.23: Part-35 starts processing at Station 3.
# 720.91: Part-49 arrives at the assembly line.
# 721.25: Part-48 finishes at Station 1.
# 721.25: Part-48 attempts to move to Buffer 1->2.
# 721.25: Part-48 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 721.25: Part-49 starts processing at Station 1.
# 721.25: Part-48 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 722.23: Part-35 finishes at Station 3.
# 722.23: Part-35 has COMPLETED the line and exits.
# 726.59: Part-50 arrives at the assembly line.
# 728.16: Part-51 arrives at the assembly line.
# 731.25: Part-49 finishes at Station 1.
# 731.25: Part-49 attempts to move to Buffer 1->2.
# 731.25: Part-49 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 731.25: Part-50 starts processing at Station 1.
# 731.25: Part-49 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 734.23: Part-36 finishes at Station 2.
# 734.23: Part-36 attempts to move to Buffer 2->3.
# 734.23: Part-36 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 734.23: Part-37 starts processing at Station 2.
# 734.23: Part-36 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 734.23: Part-36 starts processing at Station 3.
# 741.25: Part-50 finishes at Station 1.
# 741.25: Part-50 attempts to move to Buffer 1->2.
# 741.25: Part-50 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 741.25: Part-51 starts processing at Station 1.
# 741.25: Part-50 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 741.71: Part-52 arrives at the assembly line.
# 742.23: Part-36 finishes at Station 3.
# 742.23: Part-36 has COMPLETED the line and exits.
# 751.25: Part-51 finishes at Station 1.
# 751.25: Part-51 attempts to move to Buffer 1->2.
# 751.25: Part-51 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 751.25: Part-52 starts processing at Station 1.
# 751.25: Part-51 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 754.23: Part-37 finishes at Station 2.
# 754.23: Part-37 attempts to move to Buffer 2->3.
# 754.23: Part-37 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 754.23: Part-38 starts processing at Station 2.
# 754.23: Part-37 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 754.23: Part-37 starts processing at Station 3.
# 761.25: Part-52 finishes at Station 1.
# 761.25: Part-52 attempts to move to Buffer 1->2.
# 761.25: Part-52 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 761.25: Part-52 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 762.23: Part-37 finishes at Station 3.
# 762.23: Part-37 has COMPLETED the line and exits.
# 774.05: Part-53 arrives at the assembly line.
# 774.05: Part-53 starts processing at Station 1.
# 774.23: Part-38 finishes at Station 2.
# 774.23: Part-38 attempts to move to Buffer 2->3.
# 774.23: Part-38 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 774.23: Part-39 starts processing at Station 2.
# 774.23: Part-38 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 774.23: Part-38 starts processing at Station 3.
# 782.23: Part-38 finishes at Station 3.
# 782.23: Part-38 has COMPLETED the line and exits.
# 784.05: Part-53 finishes at Station 1.
# 784.05: Part-53 attempts to move to Buffer 1->2.
# 784.05: Part-53 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 784.05: Part-53 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 784.28: Part-54 arrives at the assembly line.
# 784.28: Part-54 starts processing at Station 1.
# 794.23: Part-39 finishes at Station 2.
# 794.23: Part-39 attempts to move to Buffer 2->3.
# 794.23: Part-39 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 794.23: Part-40 starts processing at Station 2.
# 794.23: Part-39 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 794.23: Part-39 starts processing at Station 3.
# 794.28: Part-54 finishes at Station 1.
# 794.28: Part-54 attempts to move to Buffer 1->2.
# 794.28: Part-54 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 794.28: Part-54 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 802.23: Part-39 finishes at Station 3.
# 802.23: Part-39 has COMPLETED the line and exits.
# 814.23: Part-40 finishes at Station 2.
# 814.23: Part-40 attempts to move to Buffer 2->3.
# 814.23: Part-40 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 814.23: Part-41 starts processing at Station 2.
# 814.23: Part-40 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 814.23: Part-40 starts processing at Station 3.
# 822.23: Part-40 finishes at Station 3.
# 822.23: Part-40 has COMPLETED the line and exits.
# 834.23: Part-41 finishes at Station 2.
# 834.23: Part-41 attempts to move to Buffer 2->3.
# 834.23: Part-41 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 834.23: Part-42 starts processing at Station 2.
# 834.23: Part-41 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 834.23: Part-41 starts processing at Station 3.
# 837.61: Part-55 arrives at the assembly line.
# 837.61: Part-55 starts processing at Station 1.
# 842.23: Part-41 finishes at Station 3.
# 842.23: Part-41 has COMPLETED the line and exits.
# 847.61: Part-55 finishes at Station 1.
# 847.61: Part-55 attempts to move to Buffer 1->2.
# 847.61: Part-55 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 847.61: Part-55 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 854.23: Part-42 finishes at Station 2.
# 854.23: Part-42 attempts to move to Buffer 2->3.
# 854.23: Part-42 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 854.23: Part-43 starts processing at Station 2.
# 854.23: Part-42 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 854.23: Part-42 starts processing at Station 3.
# 862.23: Part-42 finishes at Station 3.
# 862.23: Part-42 has COMPLETED the line and exits.
# 862.65: Part-56 arrives at the assembly line.
# 862.65: Part-56 starts processing at Station 1.
# 872.65: Part-56 finishes at Station 1.
# 872.65: Part-56 attempts to move to Buffer 1->2.
# 872.65: Part-56 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 872.65: Part-56 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 874.23: Part-43 finishes at Station 2.
# 874.23: Part-43 attempts to move to Buffer 2->3.
# 874.23: Part-43 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 874.23: Part-44 starts processing at Station 2.
# 874.23: Part-43 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 874.23: Part-43 starts processing at Station 3.
# 882.23: Part-43 finishes at Station 3.
# 882.23: Part-43 has COMPLETED the line and exits.
# 884.52: Part-57 arrives at the assembly line.
# 884.52: Part-57 starts processing at Station 1.
# 894.23: Part-44 finishes at Station 2.
# 894.23: Part-44 attempts to move to Buffer 2->3.
# 894.23: Part-44 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 894.23: Part-45 starts processing at Station 2.
# 894.23: Part-44 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 894.23: Part-44 starts processing at Station 3.
# 894.52: Part-57 finishes at Station 1.
# 894.52: Part-57 attempts to move to Buffer 1->2.
# 894.52: Part-57 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 894.52: Part-57 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 902.23: Part-44 finishes at Station 3.
# 902.23: Part-44 has COMPLETED the line and exits.
# 914.23: Part-45 finishes at Station 2.
# 914.23: Part-45 attempts to move to Buffer 2->3.
# 914.23: Part-45 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 914.23: Part-46 starts processing at Station 2.
# 914.23: Part-45 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 914.23: Part-45 starts processing at Station 3.
# 922.23: Part-45 finishes at Station 3.
# 922.23: Part-45 has COMPLETED the line and exits.
# 927.72: Part-58 arrives at the assembly line.
# 927.72: Part-58 starts processing at Station 1.
# 934.23: Part-46 finishes at Station 2.
# 934.23: Part-46 attempts to move to Buffer 2->3.
# 934.23: Part-46 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 934.23: Part-47 starts processing at Station 2.
# 934.23: Part-46 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 934.23: Part-46 starts processing at Station 3.
# 937.72: Part-58 finishes at Station 1.
# 937.72: Part-58 attempts to move to Buffer 1->2.
# 937.72: Part-58 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 937.72: Part-58 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 942.23: Part-46 finishes at Station 3.
# 942.23: Part-46 has COMPLETED the line and exits.
# 954.23: Part-47 finishes at Station 2.
# 954.23: Part-47 attempts to move to Buffer 2->3.
# 954.23: Part-47 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 954.23: Part-48 starts processing at Station 2.
# 954.23: Part-47 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 954.23: Part-47 starts processing at Station 3.
# 962.23: Part-47 finishes at Station 3.
# 962.23: Part-47 has COMPLETED the line and exits.
# 974.23: Part-48 finishes at Station 2.
# 974.23: Part-48 attempts to move to Buffer 2->3.
# 974.23: Part-48 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 974.23: Part-49 starts processing at Station 2.
# 974.23: Part-48 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 974.23: Part-48 starts processing at Station 3.
# 977.11: Part-59 arrives at the assembly line.
# 977.11: Part-59 starts processing at Station 1.
# 982.23: Part-48 finishes at Station 3.
# 982.23: Part-48 has COMPLETED the line and exits.
# 985.02: Part-60 arrives at the assembly line.
# 987.11: Part-59 finishes at Station 1.
# 987.11: Part-59 attempts to move to Buffer 1->2.
# 987.11: Part-59 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 987.11: Part-60 starts processing at Station 1.
# 987.11: Part-59 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
# 990.56: Part-61 arrives at the assembly line.
# 994.23: Part-49 finishes at Station 2.
# 994.23: Part-49 attempts to move to Buffer 2->3.
# 994.23: Part-49 ENTERS Buffer 2->3. (Buffer level: 1/10)
# 994.23: Part-50 starts processing at Station 2.
# 994.23: Part-49 EXITS Buffer 2->3, moves to Station 3. (Buffer level: 0/10)
# 994.23: Part-49 starts processing at Station 3.
# 997.11: Part-60 finishes at Station 1.
# 997.11: Part-60 attempts to move to Buffer 1->2.
# 997.11: Part-60 ENTERS Buffer 1->2. (Buffer level: 1/10)
# 997.11: Part-61 starts processing at Station 1.
# 997.11: Part-60 EXITS Buffer 1->2, moves to Station 2. (Buffer level: 0/10)
#
# --- Simulation Finished ---
# Total simulation time: 1000 minutes.
# Total parts completed: 48.
# Throughput: 2.88 units per hour.
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'd:\rl-assembly-line-optimization\rl-assembly-line-optimization\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install simpy -q

import simpy
import random
import statistics
import numpy as np

# --- Simulation Parameters ---
BUFFER_CAPACITY = 10
INTER_ARRIVAL_TIME = 10
SIM_TIME = 10000 # Run for longer to see the effects of priorities and failures

# NEW: Parameters for the rework loop
FAIL_RATE = 0.10  # 8% of parts fail testing at Station 2
REPAIR_TIME = 30  # Time it takes to repair a failed part

# --- Part Configurations and Production Mix ---
PART_CONFIGS = {
    'Type_A': {'s1_time': 10, 's2_time': 20, 's3_time': 8},
    'Type_B': {'s1_time': 12, 's2_time': 25, 's3_time': 7},
    'Type_C': {'s1_time': 8,  's2_time': 18, 's3_time': 9},
}
PART_MIX = {'Type_A': 0.60, 'Type_B': 0.25, 'Type_C': 0.15}
PART_TYPES = list(PART_MIX.keys())
PART_PROBABILITIES = list(PART_MIX.values())

# NEW: Priority Mix (e.g., 20% HIGH priority, 80% LOW priority)
PRIORITY_MIX = {'HIGH': 0.20, 'LOW': 0.80}
# In SimPy, lower number = higher priority
PRIORITY_MAP = {'HIGH': 1, 'LOW': 2}


# --- Data Collection Structures ---
cycle_times_by_priority = {1: [], 2: []} # Store cycle times for HIGH and LOW priority parts separately
wip_log = []
station_busy_time = {'station1': 0, 'station2': 0, 'station3': 0, 'repair_station': 0}
parts_processed_per_station = {'station1': 0, 'station2': 0, 'station3': 0}


def part_process(env, part_name, part_priority, part_config, stations, buffers):
    arrival_time = env.now

    # --- Process at Station 1 ---
    # MODIFIED: Requesting with priority
    with stations['station1'].request(priority=part_priority) as req:
        yield req
        start_proc_time = env.now
        yield env.timeout(part_config['s1_time'])
        station_busy_time['station1'] += env.now - start_proc_time
        parts_processed_per_station['station1'] += 1

    yield buffers['buffer12'].put(1)

    # --- NEW: Test/Rework Loop for Station 2 ---
    tested_successfully = False
    while not tested_successfully:
        # --- Process at Station 2 (Testing) ---
        with stations['station2'].request(priority=part_priority) as req:
            yield req
            yield buffers['buffer12'].get(1)
            start_proc_time = env.now
            yield env.timeout(part_config['s2_time'])
            station_busy_time['station2'] += env.now - start_proc_time

        # --- Decision Point: Test Pass or Fail? ---
        if random.random() > FAIL_RATE:
            tested_successfully = True
            parts_processed_per_station['station2'] += 1 # Count only successful tests
            yield buffers['buffer23'].put(1)
        else:
            # Part failed, send to repair
            # print(f"{env.now:.2f}: {part_name} FAILED test. Rerouting to Repair.")
            with stations['repair_station'].request(priority=part_priority) as repair_req:
                yield repair_req
                start_repair_time = env.now
                yield env.timeout(REPAIR_TIME)
                station_busy_time['repair_station'] += env.now - start_repair_time

            # After repair, it needs to go back into the queue for Station 2
            yield buffers['buffer12'].put(1)

    # --- Process at Station 3 ---
    with stations['station3'].request(priority=part_priority) as req:
        yield req
        yield buffers['buffer23'].get(1)
        start_proc_time = env.now
        yield env.timeout(part_config['s3_time'])
        station_busy_time['station3'] += env.now - start_proc_time
        parts_processed_per_station['station3'] += 1

    finish_time = env.now
    cycle_times_by_priority[part_priority].append(finish_time - arrival_time)


def part_source(env, stations, buffers):
    part_id = 0
    while True:
        yield env.timeout(random.expovariate(1.0 / INTER_ARRIVAL_TIME))
        part_id += 1

        # Select part type (for processing times)
        part_type = np.random.choice(PART_TYPES, p=PART_PROBABILITIES)
        part_config = PART_CONFIGS[part_type]

        # NEW: Select part priority
        priority_name = np.random.choice(list(PRIORITY_MIX.keys()), p=list(PRIORITY_MIX.values()))
        part_priority = PRIORITY_MAP[priority_name]

        part_name = f"Part-{part_id}({part_type}, P{part_priority})"
        env.process(part_process(env, part_name, part_priority, part_config, stations, buffers))


def monitor_wip(env, buffers):
    while True:
        wip_log.append((buffers['buffer12'].level, buffers['buffer23'].level))
        yield env.timeout(10) # Monitor less frequently for long simulations

# --- Setup and Run the Simulation ---
print("--- Starting Full-Featured Simulation (Priorities & Rework) ---")
env = simpy.Environment()

# MODIFIED: All stations are now PriorityResources
stations = {
    'station1': simpy.PriorityResource(env, capacity=1),
    'station2': simpy.PriorityResource(env, capacity=1),
    'station3': simpy.PriorityResource(env, capacity=1),
    'repair_station': simpy.PriorityResource(env, capacity=1)
}
buffers = {
    'buffer12': simpy.Container(env, capacity=BUFFER_CAPACITY, init=0),
    'buffer23': simpy.Container(env, capacity=BUFFER_CAPACITY, init=0)
}

env.process(part_source(env, stations, buffers))
env.process(monitor_wip(env, buffers))
env.run(until=SIM_TIME)

# --- KPI Calculation and Reporting ---
print("\n--- Simulation Finished ---")
print(f"Total simulation time: {SIM_TIME} minutes.")

# NEW: Reporting the simulation parameters used for this run
print(f"\n--- Simulation Parameters ---")
print("Production Mix:")
for part_type, percentage in PART_MIX.items():
    print(f"  - {part_type}: {percentage:.0%}")
print("Priority Mix:")
for priority_name, percentage in PRIORITY_MIX.items():
    print(f"  - {priority_name} Priority: {percentage:.0%}")
print(f"Station 2 Fail Rate: {FAIL_RATE:.0%}")


# --- Throughput and Cycle Time ---
high_prio_parts_completed = len(cycle_times_by_priority[1])
low_prio_parts_completed = len(cycle_times_by_priority[2])
total_parts_completed = high_prio_parts_completed + low_prio_parts_completed
throughput_per_hour = total_parts_completed / (SIM_TIME / 60)

print(f"\n--- Primary KPI: Throughput ---")
print(f"Total parts completed: {total_parts_completed} (HIGH: {high_prio_parts_completed}, LOW: {low_prio_parts_completed})")
print(f"Overall Line Throughput: {throughput_per_hour:.2f} units per hour")

avg_cycle_time_high = statistics.mean(cycle_times_by_priority[1]) if high_prio_parts_completed > 0 else 0
avg_cycle_time_low = statistics.mean(cycle_times_by_priority[2]) if low_prio_parts_completed > 0 else 0

print(f"\n--- Secondary KPI: Cycle Time by Priority ---")
print(f"Average Cycle Time (HIGH Prio): {avg_cycle_time_high:.2f} minutes")
print(f"Average Cycle Time (LOW Prio):  {avg_cycle_time_low:.2f} minutes")

# --- WIP ---
final_wip_12 = buffers['buffer12'].level
final_wip_23 = buffers['buffer23'].level
print(f"\n--- Secondary KPI: Work-In-Progress (WIP) ---")
print(f"Final WIP Count in Buffer 1->2: {final_wip_12} units")
print(f"Final WIP Count in Buffer 2->3: {final_wip_23} units")

# --- Utilization ---
print(f"\n--- Secondary KPI: Station Utilization ---")
for name, resource in stations.items():
    utilization = (station_busy_time[name] / SIM_TIME) * 100
    print(f"{name.replace('_', ' ').title()} Utilization: {utilization:.2f}%")
# Out:
# --- Starting Full-Featured Simulation (Priorities & Rework) ---
#
# --- Simulation Finished ---
# Total simulation time: 10000 minutes.
#
# --- Simulation Parameters ---
# Production Mix:
#   - Type_A: 60%
#   - Type_B: 25%
#   - Type_C: 15%
# Priority Mix:
#   - HIGH Priority: 20%
#   - LOW Priority: 80%
# Station 2 Fail Rate: 10%
#
# --- Primary KPI: Throughput ---
# Total parts completed: 425 (HIGH: 92, LOW: 333)
# Overall Line Throughput: 2.55 units per hour
#
# --- Secondary KPI: Cycle Time by Priority ---
# Average Cycle Time (HIGH Prio): 2658.24 minutes
# Average Cycle Time (LOW Prio):  2946.52 minutes
#
# --- Secondary KPI: Work-In-Progress (WIP) ---
# Final WIP Count in Buffer 1->2: 10 units
# Final WIP Count in Buffer 2->3: 0 units
#
# --- Secondary KPI: Station Utilization ---
# Station1 Utilization: 99.40%
# Station2 Utilization: 99.64%
# Station3 Utilization: 33.45%
# Repair Station Utilization: 14.70%
